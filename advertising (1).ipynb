# %%
import pandas as pd #importing panda library
import numpy as np #importing numpy library
import seaborn as sns #importing seaborn library
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\mahaj\OneDrive\Desktop\btech 1'st semester\Generative AI\advertising_data.csv")
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
tv_wise=df.TV.value_counts()
tv_wise
# Out:
# TV
# 17.2     2
# 199.8    2
# 240.1    2
# 237.4    2
# 177.0    2
#         ..
# 149.7    1
# 38.2     1
# 94.2     1
# 283.6    1
# 232.1    1
# Name: count, Length: 190, dtype: int64

# %%
radio_wise=df.Radio.value_counts()
radio_wise
# Out:
# Radio
# 4.1     3
# 5.7     3
# 48.9    2
# 2.6     2
# 27.7    2
#        ..
# 28.7    1
# 41.1    1
# 35.6    1
# 3.7     1
# 8.6     1
# Name: count, Length: 167, dtype: int64

# %%
newspaper_wise=df.Newspaper.value_counts()
newspaper_wise
# Out:
# Newspaper
# 25.6    3
# 8.7     3
# 9.3     3
# 45.1    2
# 30.0    2
#        ..
# 3.7     1
# 5.8     1
# 13.8    1
# 8.1     1
# 66.2    1
# Name: count, Length: 172, dtype: int64

# %%
sales_wise=df.Sales.value_counts()
sales_wise
# Out:
# Sales
# 11.9    5
# 16.7    5
# 20.7    4
# 13.2    3
# 9.7     3
#        ..
# 26.2    1
# 6.7     1
# 5.9     1
# 14.8    1
# 25.5    1
# Name: count, Length: 121, dtype: int64

# %%
sns.set(style="darkgrid")
fig, axs=plt.subplots(2,2,figsize=(10,10))
sns.histplot(data=df,x="TV", kde=True,color="red",ax=axs[0,0])
sns.histplot(data=df,x="Radio", kde=True,color="green",ax=axs[0,1])
sns.histplot(data=df,x="Newspaper", kde=True,color="pink",ax=axs[1,0])
sns.histplot(data=df,x="Sales", kde=True,color="black",ax=axs[1,1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
sns.histplot(data=df, x="TV", kde=True, color="red", ax=axs[0]) 
sns.histplot(data=df, x="Sales", kde=True, color="Navy", ax=axs[1])
plt.show()

# %%
sns.set(style="darkgrid")
fig, axs=plt.subplots(2,2,figsize=(10,10))
sns.boxplot(data=df, x="TV", color="lime",ax=axs[0,0])
sns.boxplot(data=df, x="Radio", color="red",ax=axs[0,1])
sns.boxplot(data=df, x="Newspaper", color="blue", ax=axs[1,0])
sns.boxplot(data=df, x="Sales", color="pink", ax=axs[1,1])
plt.show()

# %%
import pingouin as pg
pg.qqplot(df['Sales'],dist="norm")
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['TV'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Radio'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Newspaper'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
df3_numeric=df.select_dtypes(include='number')

# %%
df3_numeric = df.select_dtypes(include='number')


df3_numeric.corr(method="spearman")# selecting the method as a sperman
plt.figure(figsize=(20,8))# setting the figuresize

heatmap = sns.heatmap(df3_numeric.corr(method = 'spearman').round(3), vmin=-1, 
vmax=1, annot=True) #annot = True means writting the data value in each cell.

font2= {'family':'serif','color':'green','size':20}
plt.title("Spearman Rank Correlation",font2)
plt.show()

# %%
df3_numeric.corr(method='spearman',min_periods=1)
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.056123   0.050840  0.900996
# Radio      0.056123  1.000000   0.316979  0.339949
# Newspaper  0.050840  0.316979   1.000000  0.123027
# Sales      0.900996  0.339949   0.123027  1.000000

# %%
df.select_dtypes(include=['number']).columns.tolist()
# Out:
# ['TV', 'Radio', 'Newspaper', 'Sales']

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df, x="TV",y="Sales",color="pink")
plt.title("Sales vs TV")
# Out:
# Text(0.5, 1.0, 'Sales vs TV')

# %%
plt.figure(figsize=(12,8))#isze of the plot
sns.boxplot(data=df,x="Radio", y="Sales", color="red") 
plt.title("Sales vs Radio")
# Out:
# Text(0.5, 1.0, 'Sales vs Radio')

# %%
plt.figure(figsize=(12,8))#isze of the plot
sns.boxplot(data=df,x="Newspaper", y="Sales", color="Green") 
plt.title("Sales vs Newspaper")
# Out:
# Text(0.5, 1.0, 'Sales vs Newspaper')

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='TV',y='Sales',data=df,palette='winter')
# Out:
# C:\Users\mahaj\AppData\Local\Temp\ipykernel_13224\972752660.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='TV',y='Sales',data=df,palette='winter')
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='Radio',y='Sales',data=df,palette='winter')
# Out:
# C:\Users\mahaj\AppData\Local\Temp\ipykernel_13224\3545882843.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Radio',y='Sales',data=df,palette='winter')
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='Newspaper',y='Sales',data=df,palette='winter')
# Out:
# C:\Users\mahaj\AppData\Local\Temp\ipykernel_13224\2628350809.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Newspaper',y='Sales',data=df,palette='winter')
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
plt.figure(figsize=(9,7))
sns.boxplot(x='TV',y='Sales',data=df,palette='winter')
plt.title('sales vs tv')
# Out:
# C:\Users\mahaj\AppData\Local\Temp\ipykernel_13224\1327743453.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='TV',y='Sales',data=df,palette='winter')
# Text(0.5, 1.0, 'sales vs tv')

# %%
plt.figure(figsize=(9,7))
sns.boxplot(x='Radio',y='Sales',data=df,palette='winter')
plt.title('sales vs radio')
# Out:
# C:\Users\mahaj\AppData\Local\Temp\ipykernel_13224\1111758488.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Radio',y='Sales',data=df,palette='winter')
# Text(0.5, 1.0, 'sales vs radio')

# %%
plt.figure(figsize=(9,7))
sns.boxplot(x='Newspaper',y='Sales',data=df,palette='winter')
plt.title('sales vs newpaper')
# Out:
# C:\Users\mahaj\AppData\Local\Temp\ipykernel_13224\729965597.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Newspaper',y='Sales',data=df,palette='winter')
# Text(0.5, 1.0, 'sales vs newpaper')

# %%
plt.figure(figsize=(15,10))
plt.xlabel("TV",fontsize=15)
plt.ylabel("Sales",fontsize=10)
plt.title('sales vs tv',fontsize=15)
sns.scatterplot(x=df['TV'],y=df['Sales'],color='blue')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Radio",fontsize=15)
plt.ylabel("Sales",fontsize=10)
plt.title('sales vs radio',fontsize=15)
sns.scatterplot(x=df['Radio'],y=df['Sales'],color='blue')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Newspaper",fontsize=15)
plt.ylabel("Sales",fontsize=10)
plt.title('sales vs newspaper',fontsize=15)
sns.scatterplot(x=df['Newspaper'],y=df['Sales'],color='blue')
plt.show()

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='TV')

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column="Sales")

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column="Radio")

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column="Newspaper")

# %%
df3_numeric = df.select_dtypes(include='number')
# Spearman rank correlation heatmap

df3_numeric.corr(method="spearman")# selecting the method as a sperman
plt.figure(figsize=(20,8))# setting the figuresize

heatmap = sns.heatmap(df3_numeric.corr(method = 'spearman').round(3), vmin=-1, 
vmax=1, annot=True) #annot = True means writting the data value in each cell.

font2= {'family':'serif','color':'green','size':20}
plt.title("Spearman Rank Correlation",font2)
plt.show()

# %%
df3_numeric=df.select_dtypes(include='number')
df3_numeric.corr(method='spearman')*100
# Out:
#                    TV       Radio   Newspaper       Sales
# TV         100.000000    5.612339    5.083973   90.099564
# Radio        5.612339  100.000000   31.697949   33.994909
# Newspaper    5.083973   31.697949  100.000000   12.302741
# Sales       90.099564   33.994909   12.302741  100.000000

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
Q1=df.quantile(0.25).round(3)
Q3=df.quantile(0.75).round(3)
IQR=Q3-Q1
print(IQR)
# Out:
# TV           144.45
# Radio         26.55
# Newspaper     32.35
# Sales          8.05
# dtype: float64

# %%
dfout=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]
dfout.shape
# Out:
# (198, 4)

# %%
sns.boxplot(x=dfout['Newspaper'])
# Out:
# <Axes: xlabel='Newspaper'>

# %%
sns.boxplot(x=dfout['TV'])
# Out:
# <Axes: xlabel='TV'>

# %%
sns.boxplot(x=dfout['Radio'])
# Out:
# <Axes: xlabel='Radio'>

# %%
sns.boxplot(x=dfout['Sales'])
# Out:
# <Axes: xlabel='Sales'>

# %%
x=df.drop(["Sales"],axis=1)
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df["Sales"]
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,
                                              random_state=0)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 131  265.2    2.9       43.0
# 96   197.6    3.5        5.9
# 181  218.5    5.4       27.4
# 19   147.3   23.9       19.1
# 153  171.3   39.7       37.7
# ..     ...    ...        ...
# 67   139.3   14.5       10.2
# 192   17.2    4.1       31.6
# 117   76.4    0.8       14.8
# 47   239.9   41.5       18.5
# 172   19.6   20.1       17.0
#
# [140 rows x 3 columns]

# %%
y_train
# Out:
# 131    17.7
# 96     16.7
# 181    17.2
# 19     14.6
# 153    16.0
#        ...
# 67     13.4
# 192     5.9
# 117     9.4
# 47     23.2
# 172     7.6
# Name: Sales, Length: 140, dtype: float64

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 18    69.2   20.5       18.3
# 170   50.0   11.6       18.4
# 107   90.4    0.3       23.2
# 98   289.7   42.3       51.2
# 177  170.2    7.8       35.2
# 182   56.2    5.7       29.7
# 5      8.7   48.9       75.0
# 146  240.1    7.3        8.7
# 12    23.8   35.1       65.9
# 152  197.6   23.3       14.2
# 61   261.3   42.7       54.7
# 125   87.2   11.8       25.9
# 180  156.6    2.6        8.3
# 154  187.8   21.1        9.5
# 80    76.4   26.7       22.3
# 7    120.2   19.6       11.6
# 33   265.6   20.0        0.3
# 130    0.7   39.6        8.7
# 37    74.7   49.4       45.7
# 74   213.4   24.6       13.1
# 183  287.6   43.0       71.8
# 145  140.3    1.9        9.0
# 45   175.1   22.5       31.5
# 159  131.7   18.4       34.6
# 60    53.5    2.0       21.4
# 123  123.1   34.6       12.4
# 179  165.6   10.0       17.6
# 185  205.0   45.1       19.6
# 122  224.0    2.4       15.6
# 44    25.1   25.7       43.3
# 16    67.8   36.6      114.0
# ...

# %%
y_test
# Out:
# 18     11.3
# 170     8.4
# 107    12.0
# 98     25.4
# 177    16.7
# 182     8.7
# 5       7.2
# 146    18.2
# 12      9.2
# 152    16.6
# 61     24.2
# 125    10.6
# 180    15.5
# 154    20.6
# 80     11.8
# 7      13.2
# 33     17.4
# 130     1.6
# 37     14.7
# 74     17.0
# 183    26.2
# 145    10.3
# 45     16.1
# 159    12.9
# 60      8.1
# 123    15.2
# 179    17.6
# 185    22.6
# 122    16.6
# 44      8.5
# 16     12.5
# 55     23.7
# 150    16.1
# 111    21.8
# 22      5.6
# 189     6.7
# 129     9.7
# 4      17.9
# 83     13.6
# 106     7.2
# 134    10.8
# 66     11.0
# 26     15.0
# 113    20.9
# 168    17.1
# 63     14.0
# 8       4.8
# 75      8.7
# 118    15.9
# 143    10.4
# 71     12.4
# 124    19.7
# 184    17.6
# 97     20.5
# 149    10.1
# 24      9.7
# 30     21.4
# 160    16.4
# 40     16.6
# 56      5.5
# Name: Sales, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[ 1.32803962, -1.33989652,  0.65846895],
#        [ 0.52236742, -1.30050573, -1.13713546],
#        [ 0.77145838, -1.17576822, -0.09655609],
#        [-0.07711945,  0.03878117, -0.49826812],
#        [ 0.20891802,  1.076072  ,  0.40195403],
#        [ 0.7619238 ,  0.66903383,  1.4328536 ],
#        [ 1.29824405,  0.36047263, -0.65314505],
#        [ 0.11595584,  0.88568318, -1.0645369 ],
#        [-0.63608434, -0.90003268, -1.24845325],
#        [-0.92331363,  0.27512592, -0.64830515],
#        [ 0.37100592,  1.35180754, -1.34041143],
#        [-0.23205641, -1.20859388, -0.97257872],
#        [ 1.42934456,  0.36703776,  1.46673293],
#        [ 1.69988833,  0.85285752,  3.4607734 ],
#        [-0.68614089, -0.55864583,  0.46003288],
#        [-0.52405299,  1.60784768,  1.06502089],
#        [ 1.21124099,  0.23573513, -1.15649508],
#        [ 0.5998359 ,  0.62964304,  0.80366607],
#        [ 1.0288921 , -0.43390832, -0.31435177],
#        [ 0.47588633,  0.79377133,  2.23627768],
# ...

# %%
x_test
# Out:
# array([[-1.00793305e+00, -1.84433311e-01, -5.36987356e-01],
#        [-1.23676302e+00, -7.68730046e-01, -5.32147452e-01],
#        [-7.55266614e-01, -1.51058995e+00, -2.99832057e-01],
#        [ 1.62003620e+00,  1.24676543e+00,  1.05534108e+00],
#        [ 1.95807971e-01, -1.01820506e+00,  2.80956431e-01],
#        [-1.16287001e+00, -1.15607283e+00,  1.47617074e-02],
#        [-1.72898583e+00,  1.68006414e+00,  2.20723825e+00],
#        [ 1.02889210e+00, -1.05103072e+00, -1.00161815e+00],
#        [-1.54902059e+00,  7.74075939e-01,  1.76680698e+00],
#        [ 5.22367415e-01, -6.09619386e-04, -7.35423423e-01],
#        [ 1.28155853e+00,  1.27302596e+00,  1.22473772e+00],
#        [-7.93404944e-01, -7.55599783e-01, -1.69154647e-01],
#        [ 3.37200719e-02, -1.35959191e+00, -1.02097776e+00],
#        [ 4.05568782e-01, -1.45042520e-01, -9.62898915e-01],
#        [-9.22121805e-01,  2.22604864e-01, -3.43391194e-01],
#        [-4.00103423e-01, -2.43519498e-01, -8.61260929e-01],
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error
model_lr = LinearRegression()
model_lr.fit(x_train,y_train)
y_pred_lr=model_lr.predict(x_test)
mae_lr = mean_absolute_error(y_test, y_pred_lr)
mse_lr = mean_squared_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(mse_lr)
mape_lr = np.mean(np.abs((y_test - y_pred_lr) / np.abs(y_test)))
accuracy_lr =100*(1-mape_lr)
print('Linear Regression Metrics:')
print('Mean Absolute Error (MAE):', mae_lr)
print('Mean Squared Error (MSE):', mse_lr)
print('Root Mean Squared Error (RMSE):', rmse_lr)
print('Mean Absolute Percentage Error (MAPE):', round(mape_lr * 100, 2))
print('Accuracy:', round(accuracy_lr, 2))
# Out:
# Linear Regression Metrics:
# Mean Absolute Error (MAE): 1.366231386845276
# Mean Squared Error (MSE): 3.938015220480287
# Root Mean Squared Error (RMSE): 1.9844433024100958
# Mean Absolute Percentage Error (MAPE): 17.22
# Accuracy: 82.78

# %%
from sklearn.tree  import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

# Make predictions
y_pred = model.predict(x_test)

# Calculate performance metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((y_test - y_pred) / np.abs(y_test)))
accuracy = 100 * (1 - mape)

# Print the performance metrics
print('Mean Absolute Error (MAE):', mae)
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
print('Accuracy:', round(accuracy, 2))
# Out:
# Mean Absolute Error (MAE): 1.335
# Mean Squared Error (MSE): 3.974500000000001
# Root Mean Squared Error (RMSE): 1.9936148073286375
# Mean Absolute Percentage Error (MAPE): 19.02
# Accuracy: 80.98

# %%
from sklearn.ensemble import RandomForestRegressor

# Create and train the Random Forest model
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(x_train, y_train)

# Make predictions
y_pred_rf = model_rf.predict(x_test)

# Calculate performance metrics
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
mape_rf = np.mean(np.abs((y_test - y_pred_rf) / np.abs(y_test)))
accuracy_rf = 100 * (1 - mape_rf)

# Print the performance metrics for Random Forest
print('Random Forest Metrics:')
print('Mean Absolute Error (MAE):', mae_rf)
print('Mean Squared Error (MSE):', mse_rf)
print('Root Mean Squared Error (RMSE):', rmse_rf)
print('Mean Absolute Percentage Error (MAPE):', round(mape_rf * 100, 2))
print('Accuracy:', round(accuracy_rf, 2))
# Out:
# Random Forest Metrics:
# Mean Absolute Error (MAE): 1.1309833333333337
# Mean Squared Error (MSE): 2.4612911833333366
# Root Mean Squared Error (RMSE): 1.5688502743516783
# Mean Absolute Percentage Error (MAPE): 14.35
# Accuracy: 85.65

# %%
pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.8/72.0 MB 11.1 MB/s eta 0:00:07
#    -- ------------------------------------- 3.7/72.0 MB 13.6 MB/s eta 0:00:06
#    --- ------------------------------------ 6.3/72.0 MB 13.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 8.9/72.0 MB 13.1 MB/s eta 0:00:05
#    ------ --------------------------------- 11.5/72.0 MB 13.2 MB/s eta 0:00:05
#    ------- -------------------------------- 14.2/72.0 MB 13.2 MB/s eta 0:00:05
#    --------- ------------------------------ 16.5/72.0 MB 12.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 19.7/72.0 MB 13.1 MB/s eta 0:00:04
#    ------------ --------------------------- 22.5/72.0 MB 13.2 MB/s eta 0:00:04
#    ------------- -------------------------- 24.9/72.0 MB 13.0 MB/s eta 0:00:04
#    -------------- ------------------------- 26.2/72.0 MB 12.6 MB/s eta 0:00:04
# ...

# %%
import xgboost as xgb

# Create and train the XGBoost model
model_xgb = xgb.XGBRegressor()
model_xgb.fit(x_train, y_train)

# Make predictions
y_pred_xgb = model_xgb.predict(x_test)

# Calculate performance metrics
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
mape_xgb = np.mean(np.abs((y_test - y_pred_xgb) / np.abs(y_test)))
accuracy_xgb = 100 * (1 - mape_xgb)

# Print the performance metrics for XGBoost
print('XGBoost Metrics:')
print('Mean Absolute Error (MAE):', mae_xgb)
print('Mean Squared Error (MSE):', mse_xgb)
print('Root Mean Squared Error (RMSE):', rmse_xgb)
print('Mean Absolute Percentage Error (MAPE):', round(mape_xgb * 100, 2))
print('Accuracy:', round(accuracy_xgb, 2))
# Out:
# XGBoost Metrics:
# Mean Absolute Error (MAE): 1.2835482501983644
# Mean Squared Error (MSE): 3.4386680767975553
# Root Mean Squared Error (RMSE): 1.8543646019048021
# Mean Absolute Percentage Error (MAPE): 17.23
# Accuracy: 82.77
